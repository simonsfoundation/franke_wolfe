# %%
import sys
if ".." not in sys.path:
    sys.path.append("..")
from franke_wolfe import fw_quadratic
import fw_draw
import numpy as np
import math

# %%
bounds = [(0, 1), (0, 4)]
(cx, cy) = (4, 2)
cx = 4
cy = 1.66666666
(C, d) = fw_quadratic.squared_distance_C_d(cx, cy)
lm = 4
options = {}
runner = fw_quadratic.FWQuadratic(C, d, bounds=bounds, options=options, iteration_limit=lm)
runner.verbose = True
#runner.vertex_ratio = 0.66
#runner.blend = False
ill = fw_draw.Illustration(runner)
ill.location((cx, cy))
ill.location((0, 0))
D = ill.get_canvas()
radius = 0.01 * np.max(ill.maxes - ill.mins)
D.circle(None, cx, cy, (ill.maxes[0]-ill.mins[0])*0.05, "red")
D = ill.draw()
D.embed()
# Out:
# optimizing array([ 0.,  0.])
# optimized at array([ 0.,  0.])
# optimizing array([-8.        , -3.33333332])
# optimized at array([ 1.,  4.])
# optimizing array([-6.        ,  4.66666668])
# optimized at array([ 1.,  0.])
# optimizing array([-6.        , -3.33333332])
# optimized at array([ 1.,  4.])
# feasible point array([ 1.,  0.])
# optimizing array([-6.        , -3.33333332])
# optimized at array([ 1.,  4.])
# next estimate array([ 1.,  2.])
# optimizing array([-6.        ,  0.66666668])
# optimized at array([ 1.,  0.])
# next estimate array([ 1.        ,  1.59036145])
# optimizing array([-6.        , -0.15261043])
# optimized at array([ 1.,  4.])
# next estimate array([ 1.        ,  1.69277108])
# optimizing array([-6.        ,  0.05220885])
# optimized at array([ 1.,  0.])
# next estimate array([ 1.        ,  1.64156627])
# <div id="jp_svg_canvas_static_199669"/>
#
# <script>
# (function () {
#     var $div = $("#jp_svg_canvas_static_199669");
#     $div.width(500.0);
#     $div.height(500.0);
#     var svg_elt = function(kind) {
#             return document.createElementNS('http://www.w3.org/2000/svg', kind);
#         };
#     var svg = svg_elt("svg");
#     var $svg = $(svg);
#     $div.append(svg);
#     $div.named_elements = {};
#     svg.setAttribute("preserveAspectRatio", "none");
#     svg.setAttribute("viewBox", "0 0 500.0 500.0");
#     var add_element = function (name, tagname, attribute_dict, style_dict, text) {
#         var element = svg_elt(tagname);
#         var $element = $(element);
#         update_element($element, attribute_dict, style_dict, text);
#         $div.named_elements[name] = $element;
#         $svg.append($element);
#     };
#     var change_element = function (name, attribute_dict, style_dict, text) {
#         var $element = $div.named_elements[name];
#         if ($element) {
#             update_element($element, attribute_dict, style_dict, text);
#         }
#     };
#     var update_element = function ($element, atts, style, text) {
#         var element = $element[0];
#         if (atts) {
#             for (var att in atts) {
#                 element.setAttribute(att, atts[att]);
#             }
#         }
#         if (style) {
#             for (var styling in style) {
#                 element.style[styling] = style[styling];
#             }
#         }
#         if (text) {
#             $element.empty();
#             var node = document.createTextNode(text);
#             $element.append(node);
#         }
#     };
#     var empty = function () {
#         $div.named_elements = {};
#         $svg.empty();
#     };
#     var delete_names = function (names) {
#         for (var i=0; i<names.length; i++) {
#             var name = names[i];
#             var $element = $div.named_elements[name];
#             if ($element) {
#                 $element.remove();
#                 delete that.named_elements[name];
#             }
#         }
#     };
#     var fit = function() {
#             // fit viewport to bounding box.
#             var bbox = svg.getBBox();
#             var vbox = "" + bbox.x + " " + bbox.y + " " + bbox.width + " " + bbox.height;
#             svg.setAttribute("viewBox", vbox);
#         };
#     add_element(null, "rect", {"y": 111.53846153846155, "x": 80.76923076923077, "height": 307.6923076923077, "fill": "cornsilk", "width": 307.6923076923077}, {}, null);
#     add_element(null, "rect", {"y": 412.8205128205128, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#fffff4", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 400.0, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#fffff2", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 387.1794871794872, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#fffff0", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 374.35897435897436, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#ffffee", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 361.53846153846155, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#ffffec", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 348.71794871794873, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#ffffeb", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 335.8974358974359, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#ffffea", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 323.0769230769231, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#ffffe9", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 310.2564102564103, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#ffffe8", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 297.43589743589746, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#ffffe8", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 284.61538461538464, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#ffffe8", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 271.7948717948718, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#ffffe8", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 258.974358974359, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#ffffe8", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 246.1538461538462, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#ffffe9", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 233.33333333333337, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#ffffea", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 220.51282051282053, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#ffffeb", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 207.69230769230774, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#ffffec", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 194.87179487179492, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#ffffee", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 182.05128205128207, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#fffff0", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 169.23076923076925, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#fffff2", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 156.41025641025647, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#fffff4", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 143.5897435897436, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#fffff7", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 130.76923076923083, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#fffff9", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 117.94871794871801, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#fffffc", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 105.12820512820514, "x": 74.35897435897436, "height": 12.82051282051282, "fill": "#ffffff", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 412.8205128205128, "x": 87.17948717948718, "height": 12.82051282051282, "fill": "#ffffef", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 400.0, "x": 87.17948717948718, "height": 12.82051282051282, "fill": "#ffffec", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 387.1794871794872, "x": 87.17948717948718, "height": 12.82051282051282, "fill": "#ffffea", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 374.35897435897436, "x": 87.17948717948718, "height": 12.82051282051282, "fill": "#ffffe8", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 361.53846153846155, "x": 87.17948717948718, "height": 12.82051282051282, "fill": "#ffffe6", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 348.71794871794873, "x": 87.17948717948718, "height": 12.82051282051282, "fill": "#ffffe5", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 335.8974358974359, "x": 87.17948717948718, "height": 12.82051282051282, "fill": "#ffffe3", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 323.0769230769231, "x": 87.17948717948718, "height": 12.82051282051282, "fill": "#ffffe2", "width": 12.82051282051282}, {}, null);
#     add_element(null, "rect", {"y": 310.2564102564103, "x": 87.17948717948

# %%
(cx, cy) = (1, 1)
cx = 5.5555
cy = 3
(C, d) = fw_quadratic.squared_distance_C_d(cx, cy)
lm = 30
options = {}
perturb = True

A_ub = [
    [-4.0/7, 1],
    [-1.0/5, -1],
    [5.0/2, -1]
]
b_ub = [3, -3, 21.0/2]
runner = fw_quadratic.FWQuadratic(C, d,
                                A_ub = A_ub,
                                b_ub = b_ub,
                                options=options, 
                                iteration_limit=lm)

runner.blend = True

ill = fw_draw.Illustration(runner)
ill.location((cx, cy))
ill.location((0, 0))
ill.location((8, 8))
D = ill.get_canvas()
radius = 0.01 * np.max(ill.maxes - ill.mins)
D.circle(None, cx, cy, (ill.maxes[0]-ill.mins[0])*0.05, "cyan")

D.line(None, 0,3,5,2, "magenta",5)
D.line(None, 0,3,7,7, "magenta",5)
D.line(None, 7,7,5,2, "magenta",5)

D = ill.draw()
D.embed()

# %%
(cx, cy) = (1, 1)
cx = 3
cy = 3
def objective_2d(a):
    [x, y] = a
    return (x - cx) ** 2 + (y - cy) ** 2
lm = 6
options = {}
perturb = True

A_ub = [
    [-4.0/7, 1],
    [-1.0/5, -1],
    [5.0/2, -1]
]
b_ub = [3, -3, 21.0/2]
bounds = [(1,6), (1,6)]
runner = fw_optimize.FrankWolfe(objective_2d, 
                                A_ub = A_ub,
                                b_ub = b_ub,
                                options=options, 
                                bounds=bounds,
                                iteration_limit=lm)
runner.blend = True
ill = fw_draw.Illustration(runner)
ill.location((cx, cy))
ill.location((0, 0))
ill.location((8, 8))
D = ill.get_canvas()
radius = 0.01 * np.max(ill.maxes - ill.mins)
D.rect(None, 1, 1, 5, 5, "#aaaaff")
D.circle(None, cx, cy, (ill.maxes[0]-ill.mins[0])*0.05, "cyan")

D.line(None, 0,3,5,2, "magenta",5)
D.line(None, 0,3,7,7, "magenta",5)
D.line(None, 7,7,5,2, "magenta",5)

D = ill.draw()
D.embed()

# %%
ill.callback_args

# %%
(cx, cy) = (1, 1)
cx = 0.666
cy = -0.1
def objective_2d(a):
    [x, y] = a
    return (x - cx) ** 2 + (y - cy) ** 2
lm = 12
options = {}
perturb = True

A_ub = [
    [-3.0, 1],
    [-3.0, -1],
    [1, 0]
]
b_ub = [0, 0, 1]
bounds = [(None, None), (None, None)]
runner = fw_optimize.FrankWolfe(objective_2d, 
                                A_ub = A_ub,
                                b_ub = b_ub,
                                options=options, 
                                bounds=bounds,
                                iteration_limit=lm)
runner.blend = False
#runner.vertex_ratio = None
ill = fw_draw.Illustration(runner)
ill.location((cx, cy))
ill.location((0, 0))
ill.location((4,4))
ill.location((4,-4))
D = ill.get_canvas()
radius = 0.01 * np.max(ill.maxes - ill.mins)
D.circle(None, cx, cy, (ill.maxes[0]-ill.mins[0])*0.05, "cyan")

D.line(None, 0,0,1,3, "magenta",5)
D.line(None, 0,0,1,-3, "magenta",5)
D.line(None, 1,-3,1,3, "magenta",5)

D = ill.draw()
D.embed()

# %%
ill.callback_args[-4:]

# %%
cb = ill.callback_args[-1]

# %%
r = cb[0]
sr = r.scalar_result
sr

# %%
r

# %%
ill.illustrate_steps()
# Out:
# illustrating 4 steps.
# <div id="jp_svg_canvas_static_199670"/>
#
# <script>
# (function () {
#     var $div = $("#jp_svg_canvas_static_199670");
#     $div.width(300.0);
#     $div.height(300.0);
#     var svg_elt = function(kind) {
#             return document.createElementNS('http://www.w3.org/2000/svg', kind);
#         };
#     var svg = svg_elt("svg");
#     var $svg = $(svg);
#     $div.append(svg);
#     $div.named_elements = {};
#     svg.setAttribute("preserveAspectRatio", "none");
#     svg.setAttribute("viewBox", "0 0 300.0 300.0");
#     var add_element = function (name, tagname, attribute_dict, style_dict, text) {
#         var element = svg_elt(tagname);
#         var $element = $(element);
#         update_element($element, attribute_dict, style_dict, text);
#         $div.named_elements[name] = $element;
#         $svg.append($element);
#     };
#     var change_element = function (name, attribute_dict, style_dict, text) {
#         var $element = $div.named_elements[name];
#         if ($element) {
#             update_element($element, attribute_dict, style_dict, text);
#         }
#     };
#     var update_element = function ($element, atts, style, text) {
#         var element = $element[0];
#         if (atts) {
#             for (var att in atts) {
#                 element.setAttribute(att, atts[att]);
#             }
#         }
#         if (style) {
#             for (var styling in style) {
#                 element.style[styling] = style[styling];
#             }
#         }
#         if (text) {
#             $element.empty();
#             var node = document.createTextNode(text);
#             $element.append(node);
#         }
#     };
#     var empty = function () {
#         $div.named_elements = {};
#         $svg.empty();
#     };
#     var delete_names = function (names) {
#         for (var i=0; i<names.length; i++) {
#             var name = names[i];
#             var $element = $div.named_elements[name];
#             if ($element) {
#                 $element.remove();
#                 delete that.named_elements[name];
#             }
#         }
#     };
#     var fit = function() {
#             // fit viewport to bounding box.
#             var bbox = svg.getBBox();
#             var vbox = "" + bbox.x + " " + bbox.y + " " + bbox.width + " " + bbox.height;
#             svg.setAttribute("viewBox", vbox);
#         };
#     add_element(null, "line", {"y1": 112.88529745741735, "x2": 101.15531539230814, "stroke": "black", "x1": 100.83549371654817, "y2": 116.4150330679504}, {}, null);
#     add_element(null, "line", {"y1": 116.4150330679504, "x2": 101.47513706806811, "stroke": "black", "x1": 101.15531539230814, "y2": 119.89407229622545}, {}, null);
#     add_element(null, "line", {"y1": 119.89407229622545, "x2": 101.79495874382808, "stroke": "black", "x1": 101.47513706806811, "y2": 123.32241514224245}, {}, null);
#     add_element(null, "line", {"y1": 123.32241514224245, "x2": 102.11478041958804, "stroke": "black", "x1": 101.79495874382808, "y2": 126.70006160600141}, {}, null);
#     add_element(null, "line", {"y1": 126.70006160600141, "x2": 102.43460209534801, "stroke": "black", "x1": 102.11478041958804, "y2": 130.02701168750235}, {}, null);
#     add_element(null, "line", {"y1": 130.02701168750235, "x2": 102.75442377110798, "stroke": "black", "x1": 102.43460209534801, "y2": 133.30326538674527}, {}, null);
#     add_element(null, "line", {"y1": 133.30326538674527, "x2": 103.07424544686796, "stroke": "black", "x1": 102.75442377110798, "y2": 136.52882270373013}, {}, null);
#     add_element(null, "line", {"y1": 136.52882270373013, "x2": 103.39406712262793, "stroke": "black", "x1": 103.07424544686796, "y2": 139.70368363845699}, {}, null);
#     add_element(null, "line", {"y1": 139.70368363845699, "x2": 103.7138887983879, "stroke": "black", "x1": 103.39406712262793, "y2": 142.82784819092581}, {}, null);
#     add_element(null, "line", {"y1": 142.82784819092581, "x2": 104.03371047414787, "stroke": "black", "x1": 103.7138887983879, "y2": 145.90131636113657}, {}, null);
#     add_element(null, "line", {"y1": 145.90131636113657, "x2": 104.35353214990783, "stroke": "black", "x1": 104.03371047414787, "y2": 148.9240881490893}, {}, null);
#     add_element(null, "line", {"y1": 148.9240881490893, "x2": 104.6733538256678, "stroke": "black", "x1": 104.35353214990783, "y2": 151.89616355478401}, {}, null);
#     add_element(null, "line", {"y1": 151.89616355478401, "x2": 104.99317550142777, "stroke": "black", "x1": 104.6733538256678, "y2": 154.8175425782207}, {}, null);
#     add_element(null, "line", {"y1": 154.8175425782207, "x2": 105.31299717718774, "stroke": "black", "x1": 104.99317550142777, "y2": 157.68822521939933}, {}, null);
#     add_element(null, "line", {"y1": 157.68822521939933, "x2": 105.63281885294771, "stroke": "black", "x1": 105.31299717718774, "y2": 160.50821147831994}, {}, null);
#     add_element(null, "line", {"y1": 160.50821147831994, "x2": 105.95264052870769, "stroke": "black", "x1": 105.63281885294771, "y2": 163.27750135498252}, {}, null);
#     add_element(null, "line", {"y1": 163.27750135498252, "x2": 106.27246220446764, "stroke": "black", "x1": 105.95264052870769, "y2": 165.99609484938708}, {}, null);
#     add_element(null, "line", {"y1": 165.99609484938708, "x2": 106.59228388022763, "stroke": "black", "x1": 106.27246220446764, "y2": 168.66399196153358}, {}, null);
#     add_element(null, "line", {"y1": 168.66399196153358, "x2": 106.91210555598759, "stroke": "black", "x1": 106.59228388022763, "y2": 171.28119269142206}, {}, null);
#     add_element(null, "line", {"y1": 171.28119269142206, "x2": 107.23192723174756, "stroke": "black", "x1": 106.91210555598759, "y2": 173.84769703905252}, {}, null);
#     add_element(null, "line", {"y1": 173.84769703905252, "x2": 107.55174890750753, "stroke": "black", "x1": 107.23192723174756, "y2": 176.36350500442495}, {}, null);
#     add_element(null, "line", {"y1": 176.36350500442495, "x2": 107.8715705832675, "stroke": "black", "x1": 107.55174890750753, "y2": 178.8286165875393}, {}, null);
#     add_element(null, "line", {"y1": 178.8286165875393, "x2": 108.19139225902747, "stroke": "black", "x1": 107.8715705832675, "y2": 181.24303178839568}, {}, null);
#     add_element(null, "line", {"y1": 181.24303178839568, "x2": 108.51121393478743, "stroke": "black", "x1": 108.19139225902747, "y2": 183.60675060699398}, {}, null);
#     add_element(null, "line", {"y1": 183.60675060699398, "x2": 108.8310356105474, "stroke": "black", "x1": 108.51121393478743, "y2": 185.91977304333426}, {}, null);
#     add_element(null, "line", {"y1": 185.91977304333426, "x2": 109.15085728630737, "stroke": "black", "x1": 108.8310356105474, "y2": 188.18209909741654}, {}, null);
#     add_element(null, "line", {"y1": 188.18209909741654, "x2": 109.47067896206735, "stroke": "black", "x1": 109.15085728630737, "y2": 190.39372876924074}, {}, null);
#     add_element(null, "line", {"y1": 190.39372876924074, "x2": 109.79050063782732, "stroke": "black", "x1": 109.47067896206735, "y2": 192.55466205880694}, {}, null);
#     add_element(null, "line", {"y1": 192.55466205880694, "x2": 110.11032231358729, "stroke": "black", "x1": 109.79050063782732, "y2": 194.66489896611509}, {}, null);
#     add_element(null, "line", {"y1": 194.66489896611509, "x2": 110.43014398934726, "stroke": "black", "x1": 110.11032231358729, "y2": 196.72443949116521}, {}, null);
#     add_element(null, "line", {"y1": 196.72443949116521, "x2": 110.74996566510723, "stroke": "black", "x1": 110.43014398934726, "y2": 198.73328363395731}, {}, null);
#     add_element(null, "line", {"y1": 198.73328363395731, "x2": 111.06978734086719, "stroke": "black", "x1": 110.74996566510723, "y2": 200.69143139449136}, {}, null);
#     add_element(null, "line", {"y1": 200.69143139449136, "x2": 111.38960901662716, "stroke": "black", "x1": 111.06978734086719, "y2": 202.59888277276738}, {}, null);
#     add_element(null, "line", {"y1": 202.59888277276738, "x2": 111.70943069238713, "stroke": "black", "x1": 111.38960901662716, "y2": 204.45563776878538}, {}, null);
#     add_element(null, "line", {"y1": 204.45563776878538, "x2": 112.0292523681471, "stroke": "black", "x1": 111.70943069
# <div id="jp_svg_canvas_static_199671"/>
#
# <script>
# (function () {
#     var $div = $("#jp_svg_canvas_static_199671");
#     $div.width(300.0);
#     $div.height(300.0);
#     var svg_elt = function(kind) {
#             return document.createElementNS('http://www.w3.org/2000/svg', kind);
#         };
#     var svg = svg_elt("svg");
#     var $svg = $(svg);
#     $div.append(svg);
#     $div.named_elements = {};
#     svg.setAttribute("preserveAspectRatio", "none");
#     svg.setAttribute("viewBox", "0 0 300.0 300.0");
#     var add_element = function (name, tagname, attribute_dict, style_dict, text) {
#         var element = svg_elt(tagname);
#         var $element = $(element);
#         update_element($element, attribute_dict, style_dict, text);
#         $div.named_elements[name] = $element;
#         $svg.append($element);
#     };
#     var change_element = function (name, attribute_dict, style_dict, text) {
#         var $element = $div.named_elements[name];
#         if ($element) {
#             update_element($element, attribute_dict, style_dict, text);
#         }
#     };
#     var update_element = function ($element, atts, style, text) {
#         var element = $element[0];
#         if (atts) {
#             for (var att in atts) {
#                 element.setAttribute(att, atts[att]);
#             }
#         }
#         if (style) {
#             for (var styling in style) {
#                 element.style[styling] = style[styling];
#             }
#         }
#         if (text) {
#             $element.empty();
#             var node = document.createTextNode(text);
#             $element.append(node);
#         }
#     };
#     var empty = function () {
#         $div.named_elements = {};
#         $svg.empty();
#     };
#     var delete_names = function (names) {
#         for (var i=0; i<names.length; i++) {
#             var name = names[i];
#             var $element = $div.named_elements[name];
#             if ($element) {
#                 $element.remove();
#                 delete that.named_elements[name];
#             }
#         }
#     };
#     var fit = function() {
#             // fit viewport to bounding box.
#             var bbox = svg.getBBox();
#             var vbox = "" + bbox.x + " " + bbox.y + " " + bbox.width + " " + bbox.height;
#             svg.setAttribute("viewBox", vbox);
#         };
#     add_element(null, "line", {"y1": 236.23935672305592, "x2": 62.233445566778897, "stroke": "black", "x1": 61.111111111111107, "y2": 236.46312123631529}, {}, null);
#     add_element(null, "line", {"y1": 236.46312123631529, "x2": 63.355780022446687, "stroke": "black", "x1": 62.233445566778897, "y2": 236.68437941013079}, {}, null);
#     add_element(null, "line", {"y1": 236.68437941013079, "x2": 64.478114478114463, "stroke": "black", "x1": 63.355780022446687, "y2": 236.90313124450228}, {}, null);
#     add_element(null, "line", {"y1": 236.90313124450228, "x2": 65.60044893378226, "stroke": "black", "x1": 64.478114478114463, "y2": 237.11937673942975}, {}, null);
#     add_element(null, "line", {"y1": 237.11937673942975, "x2": 66.722783389450058, "stroke": "black", "x1": 65.60044893378226, "y2": 237.33311589491333}, {}, null);
#     add_element(null, "line", {"y1": 237.33311589491333, "x2": 67.845117845117841, "stroke": "black", "x1": 66.722783389450058, "y2": 237.54434871095293}, {}, null);
#     add_element(null, "line", {"y1": 237.54434871095293, "x2": 68.967452300785624, "stroke": "black", "x1": 67.845117845117841, "y2": 237.75307518754855}, {}, null);
#     add_element(null, "line", {"y1": 237.75307518754855, "x2": 70.089786756453421, "stroke": "black", "x1": 68.967452300785624, "y2": 237.95929532470018}, {}, null);
#     add_element(null, "line", {"y1": 237.95929532470018, "x2": 71.212121212121218, "stroke": "black", "x1": 70.089786756453421, "y2": 238.16300912240783}, {}, null);
#     add_element(null, "line", {"y1": 238.16300912240783, "x2": 72.334455667789001, "stroke": "black", "x1": 71.212121212121218, "y2": 238.36421658067152}, {}, null);
#     add_element(null, "line", {"y1": 238.36421658067152, "x2": 73.456790123456784, "stroke": "black", "x1": 72.334455667789001, "y2": 238.56291769949127}, {}, null);
#     add_element(null, "line", {"y1": 238.56291769949127, "x2": 74.579124579124567, "stroke": "black", "x1": 73.456790123456784, "y2": 238.759112478867}, {}, null);
#     add_element(null, "line", {"y1": 238.759112478867, "x2": 75.701459034792364, "stroke": "black", "x1": 74.579124579124567, "y2": 238.9528009187988}, {}, null);
#     add_element(null, "line", {"y1": 238.9528009187988, "x2": 76.823793490460162, "stroke": "black", "x1": 75.701459034792364, "y2": 239.14398301928662}, {}, null);
#     add_element(null, "line", {"y1": 239.14398301928662, "x2": 77.946127946127945, "stroke": "black", "x1": 76.823793490460162, "y2": 239.33265878033046}, {}, null);
#     add_element(null, "line", {"y1": 239.33265878033046, "x2": 79.068462401795742, "stroke": "black", "x1": 77.946127946127945, "y2": 239.51882820193035}, {}, null);
#     add_element(null, "line", {"y1": 239.51882820193035, "x2": 80.190796857463525, "stroke": "black", "x1": 79.068462401795742, "y2": 239.70249128408625}, {}, null);
#     add_element(null, "line", {"y1": 239.70249128408625, "x2": 81.313131313131322, "stroke": "black", "x1": 80.190796857463525, "y2": 239.88364802679823}, {}, null);
#     add_element(null, "line", {"y1": 239.88364802679823, "x2": 82.435465768799105, "stroke": "black", "x1": 81.313131313131322, "y2": 240.06229843006616}, {}, null);
#     add_element(null, "line", {"y1": 240.06229843006616, "x2": 83.557800224466888, "stroke": "black", "x1": 82.435465768799105, "y2": 240.23844249389015}, {}, null);
#     add_element(null, "line", {"y1": 240.23844249389015, "x2": 84.680134680134685, "stroke": "black", "x1": 83.557800224466888, "y2": 240.41208021827018}, {}, null);
#     add_element(null, "line", {"y1": 240.41208021827018, "x2": 85.802469135802468, "stroke": "black", "x1": 84.680134680134685, "y2": 240.58321160320625}, {}, null);
#     add_element(null, "line", {"y1": 240.58321160320625, "x2": 86.924803591470265, "stroke": "black", "x1": 85.802469135802468, "y2": 240.75183664869829}, {}, null);
#     add_element(null, "line", {"y1": 240.75183664869829, "x2": 88.047138047138048, "stroke": "black", "x1": 86.924803591470265, "y2": 240.91795535474643}, {}, null);
#     add_element(null, "line", {"y1": 240.91795535474643, "x2": 89.169472502805831, "stroke": "black", "x1": 88.047138047138048, "y2": 241.08156772135061}, {}, null);
#     add_element(null, "line", {"y1": 241.08156772135061, "x2": 90.291806958473629, "stroke": "black", "x1": 89.169472502805831, "y2": 241.24267374851075}, {}, null);
#     add_element(null, "line", {"y1": 241.24267374851075, "x2": 91.414141414141426, "stroke": "black", "x1": 90.291806958473629, "y2": 241.40127343622694}, {}, null);
#     add_element(null, "line", {"y1": 241.40127343622694, "x2": 92.536475869809209, "stroke": "black", "x1": 91.414141414141426, "y2": 241.55736678449915}, {}, null);
#     add_element(null, "line", {"y1": 241.55736678449915, "x2": 93.658810325476992, "stroke": "black", "x1": 92.536475869809209, "y2": 241.71095379332743}, {}, null);
#     add_element(null, "line", {"y1": 241.71095379332743, "x2": 94.781144781144775, "stroke": "black", "x1": 93.658810325476992, "y2": 241.86203446271173}, {}, null);
#     add_element(null, "line", {"y1": 241.86203446271173, "x2": 95.903479236812572, "stroke": "black", "x1": 94.781144781144775, "y2": 242.01060879265208}, {}, null);
#     add_element(null, "line", {"y1": 242.01060879265208, "x2": 97.025813692480369, "stroke": "black", "x1": 95.903479236812572, "y2": 242.15667678314838}, {}, null);
#     add_element(null, "line", {"y1": 242.15667678314838, "x2": 98.148148148148152, "stroke": "black", "x1": 97.025813692480369, "y2": 242.30023843420082}, {}, null);
#     add_element(null, "line", {"y1": 242.30023843420082, "x2": 99.27048260381595, "stroke": "black", "x1": 98.148148148148152, "y2": 242.44129374580925}, {}, null);
#     add_element(null, "line", {"y1": 242.44129374580925, "x2": 100.39281705948373, "stroke": "black", "x1": 99.2
# <div id="jp_svg_canvas_static_199672"/>
#
# <script>
# (function () {
#     var $div = $("#jp_svg_canvas_static_199672");
#     $div.width(300.0);
#     $div.height(300.0);
#     var svg_elt = function(kind) {
#             return document.createElementNS('http://www.w3.org/2000/svg', kind);
#         };
#     var svg = svg_elt("svg");
#     var $svg = $(svg);
#     $div.append(svg);
#     $div.named_elements = {};
#     svg.setAttribute("preserveAspectRatio", "none");
#     svg.setAttribute("viewBox", "0 0 300.0 300.0");
#     var add_element = function (name, tagname, attribute_dict, style_dict, text) {
#         var element = svg_elt(tagname);
#         var $element = $(element);
#         update_element($element, attribute_dict, style_dict, text);
#         $div.named_elements[name] = $element;
#         $svg.append($element);
#     };
#     var change_element = function (name, attribute_dict, style_dict, text) {
#         var $element = $div.named_elements[name];
#         if ($element) {
#             update_element($element, attribute_dict, style_dict, text);
#         }
#     };
#     var update_element = function ($element, atts, style, text) {
#         var element = $element[0];
#         if (atts) {
#             for (var att in atts) {
#                 element.setAttribute(att, atts[att]);
#             }
#         }
#         if (style) {
#             for (var styling in style) {
#                 element.style[styling] = style[styling];
#             }
#         }
#         if (text) {
#             $element.empty();
#             var node = document.createTextNode(text);
#             $element.append(node);
#         }
#     };
#     var empty = function () {
#         $div.named_elements = {};
#         $svg.empty();
#     };
#     var delete_names = function (names) {
#         for (var i=0; i<names.length; i++) {
#             var name = names[i];
#             var $element = $div.named_elements[name];
#             if ($element) {
#                 $element.remove();
#                 delete that.named_elements[name];
#             }
#         }
#     };
#     var fit = function() {
#             // fit viewport to bounding box.
#             var bbox = svg.getBBox();
#             var vbox = "" + bbox.x + " " + bbox.y + " " + bbox.width + " " + bbox.height;
#             svg.setAttribute("viewBox", vbox);
#         };
#     add_element(null, "line", {"y1": 232.0737242579734, "x2": 62.233445566778897, "stroke": "black", "x1": 61.111111111111107, "y2": 232.59916516358868}, {}, null);
#     add_element(null, "line", {"y1": 232.59916516358868, "x2": 63.355780022446687, "stroke": "black", "x1": 62.233445566778897, "y2": 233.1148049495084}, {}, null);
#     add_element(null, "line", {"y1": 233.1148049495084, "x2": 64.478114478114463, "stroke": "black", "x1": 63.355780022446687, "y2": 233.62064361573249}, {}, null);
#     add_element(null, "line", {"y1": 233.62064361573249, "x2": 65.60044893378226, "stroke": "black", "x1": 64.478114478114463, "y2": 234.11668116226102}, {}, null);
#     add_element(null, "line", {"y1": 234.11668116226102, "x2": 66.722783389450058, "stroke": "black", "x1": 65.60044893378226, "y2": 234.60291758909395}, {}, null);
#     add_element(null, "line", {"y1": 234.60291758909395, "x2": 67.845117845117841, "stroke": "black", "x1": 66.722783389450058, "y2": 235.07935289623128}, {}, null);
#     add_element(null, "line", {"y1": 235.07935289623128, "x2": 68.967452300785624, "stroke": "black", "x1": 67.845117845117841, "y2": 235.54598708367303}, {}, null);
#     add_element(null, "line", {"y1": 235.54598708367303, "x2": 70.089786756453421, "stroke": "black", "x1": 68.967452300785624, "y2": 236.00282015141914}, {}, null);
#     add_element(null, "line", {"y1": 236.00282015141914, "x2": 71.212121212121218, "stroke": "black", "x1": 70.089786756453421, "y2": 236.44985209946972}, {}, null);
#     add_element(null, "line", {"y1": 236.44985209946972, "x2": 72.334455667789001, "stroke": "black", "x1": 71.212121212121218, "y2": 236.88708292782462}, {}, null);
#     add_element(null, "line", {"y1": 236.88708292782462, "x2": 73.456790123456784, "stroke": "black", "x1": 72.334455667789001, "y2": 237.31451263648401}, {}, null);
#     add_element(null, "line", {"y1": 237.31451263648401, "x2": 74.579124579124567, "stroke": "black", "x1": 73.456790123456784, "y2": 237.73214122544775}, {}, null);
#     add_element(null, "line", {"y1": 237.73214122544775, "x2": 75.701459034792364, "stroke": "black", "x1": 74.579124579124567, "y2": 238.13996869471595}, {}, null);
#     add_element(null, "line", {"y1": 238.13996869471595, "x2": 76.823793490460162, "stroke": "black", "x1": 75.701459034792364, "y2": 238.53799504428846}, {}, null);
#     add_element(null, "line", {"y1": 238.53799504428846, "x2": 77.946127946127945, "stroke": "black", "x1": 76.823793490460162, "y2": 238.92622027416544}, {}, null);
#     add_element(null, "line", {"y1": 238.92622027416544, "x2": 79.068462401795742, "stroke": "black", "x1": 77.946127946127945, "y2": 239.3046443843468}, {}, null);
#     add_element(null, "line", {"y1": 239.3046443843468, "x2": 80.190796857463525, "stroke": "black", "x1": 79.068462401795742, "y2": 239.67326737483262}, {}, null);
#     add_element(null, "line", {"y1": 239.67326737483262, "x2": 81.313131313131322, "stroke": "black", "x1": 80.190796857463525, "y2": 240.03208924562279}, {}, null);
#     add_element(null, "line", {"y1": 240.03208924562279, "x2": 82.435465768799105, "stroke": "black", "x1": 81.313131313131322, "y2": 240.38110999671736}, {}, null);
#     add_element(null, "line", {"y1": 240.38110999671736, "x2": 83.557800224466888, "stroke": "black", "x1": 82.435465768799105, "y2": 240.72032962811633}, {}, null);
#     add_element(null, "line", {"y1": 240.72032962811633, "x2": 84.680134680134685, "stroke": "black", "x1": 83.557800224466888, "y2": 241.04974813981977}, {}, null);
#     add_element(null, "line", {"y1": 241.04974813981977, "x2": 85.802469135802468, "stroke": "black", "x1": 84.680134680134685, "y2": 241.36936553182753}, {}, null);
#     add_element(null, "line", {"y1": 241.36936553182753, "x2": 86.924803591470265, "stroke": "black", "x1": 85.802469135802468, "y2": 241.6791818041398}, {}, null);
#     add_element(null, "line", {"y1": 241.6791818041398, "x2": 88.047138047138048, "stroke": "black", "x1": 86.924803591470265, "y2": 241.97919695675637}, {}, null);
#     add_element(null, "line", {"y1": 241.97919695675637, "x2": 89.169472502805831, "stroke": "black", "x1": 88.047138047138048, "y2": 242.2694109896774}, {}, null);
#     add_element(null, "line", {"y1": 242.2694109896774, "x2": 90.291806958473629, "stroke": "black", "x1": 89.169472502805831, "y2": 242.54982390290283}, {}, null);
#     add_element(null, "line", {"y1": 242.54982390290283, "x2": 91.414141414141426, "stroke": "black", "x1": 90.291806958473629, "y2": 242.82043569643261}, {}, null);
#     add_element(null, "line", {"y1": 242.82043569643261, "x2": 92.536475869809209, "stroke": "black", "x1": 91.414141414141426, "y2": 243.08124637026683}, {}, null);
#     add_element(null, "line", {"y1": 243.08124637026683, "x2": 93.658810325476992, "stroke": "black", "x1": 92.536475869809209, "y2": 243.3322559244055}, {}, null);
#     add_element(null, "line", {"y1": 243.3322559244055, "x2": 94.781144781144775, "stroke": "black", "x1": 93.658810325476992, "y2": 243.5734643588485}, {}, null);
#     add_element(null, "line", {"y1": 243.5734643588485, "x2": 95.903479236812572, "stroke": "black", "x1": 94.781144781144775, "y2": 243.80487167359598}, {}, null);
#     add_element(null, "line", {"y1": 243.80487167359598, "x2": 97.025813692480369, "stroke": "black", "x1": 95.903479236812572, "y2": 244.02647786864782}, {}, null);
#     add_element(null, "line", {"y1": 244.02647786864782, "x2": 98.148148148148152, "stroke": "black", "x1": 97.025813692480369, "y2": 244.23828294400406}, {}, null);
#     add_element(null, "line", {"y1": 244.23828294400406, "x2": 99.27048260381595, "stroke": "black", "x1": 98.148148148148152, "y2": 244.4402868996647}, {}, null);
#     add_element(null, "line", {"y1": 244.4402868996647, "x2": 100.39281705948373, "stroke": "black", "x1": 99.2704826038
# <div id="jp_svg_canvas_static_199673"/>
#
# <script>
# (function () {
#     var $div = $("#jp_svg_canvas_static_199673");
#     $div.width(300.0);
#     $div.height(300.0);
#     var svg_elt = function(kind) {
#             return document.createElementNS('http://www.w3.org/2000/svg', kind);
#         };
#     var svg = svg_elt("svg");
#     var $svg = $(svg);
#     $div.append(svg);
#     $div.named_elements = {};
#     svg.setAttribute("preserveAspectRatio", "none");
#     svg.setAttribute("viewBox", "0 0 300.0 300.0");
#     var add_element = function (name, tagname, attribute_dict, style_dict, text) {
#         var element = svg_elt(tagname);
#         var $element = $(element);
#         update_element($element, attribute_dict, style_dict, text);
#         $div.named_elements[name] = $element;
#         $svg.append($element);
#     };
#     var change_element = function (name, attribute_dict, style_dict, text) {
#         var $element = $div.named_elements[name];
#         if ($element) {
#             update_element($element, attribute_dict, style_dict, text);
#         }
#     };
#     var update_element = function ($element, atts, style, text) {
#         var element = $element[0];
#         if (atts) {
#             for (var att in atts) {
#                 element.setAttribute(att, atts[att]);
#             }
#         }
#         if (style) {
#             for (var styling in style) {
#                 element.style[styling] = style[styling];
#             }
#         }
#         if (text) {
#             $element.empty();
#             var node = document.createTextNode(text);
#             $element.append(node);
#         }
#     };
#     var empty = function () {
#         $div.named_elements = {};
#         $svg.empty();
#     };
#     var delete_names = function (names) {
#         for (var i=0; i<names.length; i++) {
#             var name = names[i];
#             var $element = $div.named_elements[name];
#             if ($element) {
#                 $element.remove();
#                 delete that.named_elements[name];
#             }
#         }
#     };
#     var fit = function() {
#             // fit viewport to bounding box.
#             var bbox = svg.getBBox();
#             var vbox = "" + bbox.x + " " + bbox.y + " " + bbox.width + " " + bbox.height;
#             svg.setAttribute("viewBox", vbox);
#         };
#     add_element(null, "line", {"y1": 245.83394859717086, "x2": 62.233445566778897, "stroke": "black", "x1": 61.111111111111107, "y2": 245.84409802167326}, {}, null);
#     add_element(null, "line", {"y1": 245.84409802167326, "x2": 63.355780022446687, "stroke": "black", "x1": 62.233445566778897, "y2": 245.85408272998703}, {}, null);
#     add_element(null, "line", {"y1": 245.85408272998703, "x2": 64.478114478114463, "stroke": "black", "x1": 63.355780022446687, "y2": 245.86390272211227}, {}, null);
#     add_element(null, "line", {"y1": 245.86390272211227, "x2": 65.60044893378226, "stroke": "black", "x1": 64.478114478114463, "y2": 245.87355799804902}, {}, null);
#     add_element(null, "line", {"y1": 245.87355799804902, "x2": 66.722783389450058, "stroke": "black", "x1": 65.60044893378226, "y2": 245.88304855779714}, {}, null);
#     add_element(null, "line", {"y1": 245.88304855779714, "x2": 67.845117845117841, "stroke": "black", "x1": 66.722783389450058, "y2": 245.8923744013567}, {}, null);
#     add_element(null, "line", {"y1": 245.8923744013567, "x2": 68.967452300785624, "stroke": "black", "x1": 67.845117845117841, "y2": 245.90153552872772}, {}, null);
#     add_element(null, "line", {"y1": 245.90153552872772, "x2": 70.089786756453421, "stroke": "black", "x1": 68.967452300785624, "y2": 245.91053193991016}, {}, null);
#     add_element(null, "line", {"y1": 245.91053193991016, "x2": 71.212121212121218, "stroke": "black", "x1": 70.089786756453421, "y2": 245.91936363490404}, {}, null);
#     add_element(null, "line", {"y1": 245.91936363490404, "x2": 72.334455667789001, "stroke": "black", "x1": 71.212121212121218, "y2": 245.92803061370938}, {}, null);
#     add_element(null, "line", {"y1": 245.92803061370938, "x2": 73.456790123456784, "stroke": "black", "x1": 72.334455667789001, "y2": 245.93653287632614}, {}, null);
#     add_element(null, "line", {"y1": 245.93653287632614, "x2": 74.579124579124567, "stroke": "black", "x1": 73.456790123456784, "y2": 245.94487042275435}, {}, null);
#     add_element(null, "line", {"y1": 245.94487042275435, "x2": 75.701459034792364, "stroke": "black", "x1": 74.579124579124567, "y2": 245.95304325299398}, {}, null);
#     add_element(null, "line", {"y1": 245.95304325299398, "x2": 76.823793490460162, "stroke": "black", "x1": 75.701459034792364, "y2": 245.96105136704509}, {}, null);
#     add_element(null, "line", {"y1": 245.96105136704509, "x2": 77.946127946127945, "stroke": "black", "x1": 76.823793490460162, "y2": 245.96889476490762}, {}, null);
#     add_element(null, "line", {"y1": 245.96889476490762, "x2": 79.068462401795742, "stroke": "black", "x1": 77.946127946127945, "y2": 245.97657344658157}, {}, null);
#     add_element(null, "line", {"y1": 245.97657344658157, "x2": 80.190796857463525, "stroke": "black", "x1": 79.068462401795742, "y2": 245.98408741206703}, {}, null);
#     add_element(null, "line", {"y1": 245.98408741206703, "x2": 81.313131313131322, "stroke": "black", "x1": 80.190796857463525, "y2": 245.99143666136379}, {}, null);
#     add_element(null, "line", {"y1": 245.99143666136379, "x2": 82.435465768799105, "stroke": "black", "x1": 81.313131313131322, "y2": 245.99862119447209}, {}, null);
#     add_element(null, "line", {"y1": 245.99862119447209, "x2": 83.557800224466888, "stroke": "black", "x1": 82.435465768799105, "y2": 246.00564101139187}, {}, null);
#     add_element(null, "line", {"y1": 246.00564101139187, "x2": 84.680134680134685, "stroke": "black", "x1": 83.557800224466888, "y2": 246.01249611212302}, {}, null);
#     add_element(null, "line", {"y1": 246.01249611212302, "x2": 85.802469135802468, "stroke": "black", "x1": 84.680134680134685, "y2": 246.01918649666561}, {}, null);
#     add_element(null, "line", {"y1": 246.01918649666561, "x2": 86.924803591470265, "stroke": "black", "x1": 85.802469135802468, "y2": 246.02571216501968}, {}, null);
#     add_element(null, "line", {"y1": 246.02571216501968, "x2": 88.047138047138048, "stroke": "black", "x1": 86.924803591470265, "y2": 246.03207311718512}, {}, null);
#     add_element(null, "line", {"y1": 246.03207311718512, "x2": 89.169472502805831, "stroke": "black", "x1": 88.047138047138048, "y2": 246.03826935316204}, {}, null);
#     add_element(null, "line", {"y1": 246.03826935316204, "x2": 90.291806958473629, "stroke": "black", "x1": 89.169472502805831, "y2": 246.0443008729504}, {}, null);
#     add_element(null, "line", {"y1": 246.0443008729504, "x2": 91.414141414141426, "stroke": "black", "x1": 90.291806958473629, "y2": 246.05016767655022}, {}, null);
#     add_element(null, "line", {"y1": 246.05016767655022, "x2": 92.536475869809209, "stroke": "black", "x1": 91.414141414141426, "y2": 246.05586976396143}, {}, null);
#     add_element(null, "line", {"y1": 246.05586976396143, "x2": 93.658810325476992, "stroke": "black", "x1": 92.536475869809209, "y2": 246.06140713518408}, {}, null);
#     add_element(null, "line", {"y1": 246.06140713518408, "x2": 94.781144781144775, "stroke": "black", "x1": 93.658810325476992, "y2": 246.06677979021822}, {}, null);
#     add_element(null, "line", {"y1": 246.06677979021822, "x2": 95.903479236812572, "stroke": "black", "x1": 94.781144781144775, "y2": 246.07198772906378}, {}, null);
#     add_element(null, "line", {"y1": 246.07198772906378, "x2": 97.025813692480369, "stroke": "black", "x1": 95.903479236812572, "y2": 246.07703095172079}, {}, null);
#     add_element(null, "line", {"y1": 246.07703095172079, "x2": 98.148148148148152, "stroke": "black", "x1": 97.025813692480369, "y2": 246.08190945818924}, {}, null);
#     add_element(null, "line", {"y1": 246.08190945818924, "x2": 99.27048260381595, "stroke": "black", "x1": 98.148148148148152, "y2": 246.08662324846907}, {}, null);
#     add_element(null, "line", {"y1": 246.08662324846907, "x2": 100.39281705948373, "stroke": "black", "x1": 99

# %%
a.T

# %%
rs.test = "whatever"

# %%
rs

# %%
xc = 1
yc = -4

def algebraic(x, y):
    return (x - xc) ** 2 + (y - yc) ** 2

def matrices(x, y):
    C = np.array([[1, 0], [0, 1]])
    d = -2 * np.array([xc, yc])
    xy = np.array([x, y])
    Cpart = xy.T.dot(C).dot(xy)
    Dpart = d.T.dot(xy)
    print Cpart, Dpart
    return Cpart + Dpart + xc**2 + yc**2

# %%
algebraic(1, -4)

# %%
matrices(1, -4)

# %%
xo = 3
yo = 6
xs = 0.4
ys = 1.2
for i in range(3):
    for j in range(3):
        x = xo + xs * i
        y = yo + ys * j
        a = algebraic(x,y)
        m = matrices(x,y)
        print a, m
        assert abs(a-m) < 1e-10

# %%
from cvxopt import matrix, solvers
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-c30ea18434a5> in <module>()
# ----> 1 from cvxopt import matrix, solvers
#
# ImportError: No module named cvxopt
